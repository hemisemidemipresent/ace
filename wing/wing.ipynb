# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.array([ float(row[15:]) for row in open("data.txt").read().split('\n')])
data = data[(data < 260) & (data > 235)]

# %%
plt.plot(data[:1000])
